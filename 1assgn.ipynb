# %%
#Data assignment 1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\Taizeen\Downloads\data science assignments\Basic stats - 1\Basic stats - 1\sales_data_with_discounts.csv")
df
# Out:
#            Date       Day  SKU City  Volume         BU  Brand       Model  \
# 0    01-04-2021  Thursday  M01    C      15    Mobiles  RealU       RU-10
# 1    01-04-2021  Thursday  M02    C      10    Mobiles  RealU   RU-9 Plus
# 2    01-04-2021  Thursday  M03    C       7    Mobiles   YouM       YM-99
# 3    01-04-2021  Thursday  M04    C       6    Mobiles   YouM  YM-99 Plus
# 4    01-04-2021  Thursday  M05    C       3    Mobiles   YouM      YM-98
# ..          ...       ...  ...  ...     ...        ...    ...         ...
# 445  15-04-2021  Thursday  L06    C       2  Lifestyle  Jeera   M-Casuals
# 446  15-04-2021  Thursday  L07    C       6  Lifestyle   Viva   W-Western
# 447  15-04-2021  Thursday  L08    C       2  Lifestyle   Viva    W-Lounge
# 448  15-04-2021  Thursday  L09    C       3  Lifestyle  Jeera   M-Formals
# 449  15-04-2021  Thursday  L10    C       1  Lifestyle  Jeera     M-Shoes
#
#      Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# ...

# %%
#Avg price

# %%
import statistics
median_value = statistics.median(df["Avg Price"])
print(median_value)
# Out:
# 1450.0

# %%
import statistics
mean_value = statistics.mean(df["Avg Price"])
print(mean_value)
# Out:
# 10453.433333333332

# %%
import statistics
mode_value = statistics.mode(df["Avg Price"])
print(mode_value)
# Out:
# 8100

# %%
import statistics
std_value = statistics.stdev(df["Avg Price"])
print(std_value)
# Out:
# 18079.90483993647

# %%
#Total sales value

# %%
import statistics
median_sales = statistics.median(df["Total Sales Value"])
print(median_sales)
# Out:
# 5700.0

# %%
import statistics
mean_sales = statistics.mean(df["Total Sales Value"])
print(mean_sales)
# Out:
# 33812.83555555555

# %%
import statistics
mode_sales = statistics.mode(df["Total Sales Value"])
print(mode_sales)
# Out:
# 24300

# %%
import statistics
std_sales = statistics.stdev(df["Total Sales Value"])
print(std_sales)
# Out:
# 50535.07417255326

# %%
#discount rate

# %%
import statistics
median_discount = statistics.median(df["Discount Rate (%)"])
print(median_discount)
# Out:
# 16.57776564929597

# %%
import statistics
mean_discount = statistics.mean(df["Discount Rate (%)"])
print(mean_discount)
# Out:
# 15.155241895330914

# %%
import statistics
mode_discount = statistics.mode(df["Discount Rate (%)"])
print(mode_discount)
# Out:
# 11.654820286277229

# %%
import statistics
std_discount = statistics.stdev(df["Discount Rate (%)"])
print(std_discount)
# Out:
# 4.220602153325509

# %%
#discount amount

# %%
import statistics
std_discount_amount= statistics.stdev(df["Discount Amount"])
print(std_discount_amount)
# Out:
# 4509.9029633539985

# %%
import statistics
mean_discount_amount= statistics.mean(df["Discount Amount"])
print(std_discount_amount)
# Out:
# 4509.9029633539985

# %%
import statistics
mode_discount_amount= statistics.mode(df["Discount Amount"])
print(std_discount_amount)
# Out:
# 4509.9029633539985

# %%
import statistics
median_discount_amount= statistics.median(df["Discount Amount"])
print(std_discount_amount)
# Out:
# 4509.9029633539985

# %%
#net sales value

# %%
import statistics
median_net= statistics.median(df["Net Sales Value"])
print(median_net)
# Out:
# 4677.788059301853

# %%
import statistics
mean_net= statistics.mean(df["Net Sales Value"])
print(mean_net)
# Out:
# 30466.336131270138

# %%
import statistics
mode_net= statistics.mode(df["Net Sales Value"])
print(mode_net)
# Out:
# 160346.50118040683

# %%
import statistics
std_net= statistics.stdev(df["Net Sales Value"])
print(std_net)
# Out:
# 46358.65662406695

# %%
num_cols = df.select_dtypes(include='number')

# 3. Histograms
for col in num_cols.columns:
    plt.figure(figsize=(6,4))
    plt.hist(df[col], bins=20, edgecolor='black')
    plt.title(f"Histogram of {col}")
    plt.xlabel(col)
    plt.ylabel("Frequency")
    plt.show()

# %%
# 4. Boxplots
for col in num_cols.columns:
    plt.figure(figsize=(6,4))
    plt.boxplot(df[col], vert=False)
    plt.title(f"Boxplot of {col}")
    plt.xlabel(col)
    plt.show()

# %%
# 5. Bar Charts for Categorical Columns
cat_cols = df.select_dtypes(include='object').columns
for col in cat_cols:
    plt.figure(figsize=(6,4))
    df[col].value_counts().plot(kind='bar')
    plt.title(f"Bar Chart of {col}")
    plt.xlabel(col)
    plt.ylabel("Count")
    plt.show()

# %%
# 6. Standardization (Z-score normalization)
standardized_df = df.copy()
for col in num_cols.columns:
    standardized_df[col + "_zscore"] = (df[col] - df[col].mean()) / df[col].std()

print("===== Standardized Columns (Z-scores) =====")
print(standardized_df.head())
# Out:
# ===== Standardized Columns (Z-scores) =====
#          Date       Day  SKU City  Volume       BU  Brand       Model  \
# 0  01-04-2021  Thursday  M01    C      15  Mobiles  RealU       RU-10
# 1  01-04-2021  Thursday  M02    C      10  Mobiles  RealU   RU-9 Plus
# 2  01-04-2021  Thursday  M03    C       7  Mobiles   YouM       YM-99
# 3  01-04-2021  Thursday  M04    C       6  Mobiles   YouM  YM-99 Plus
# 4  01-04-2021  Thursday  M05    C       3  Mobiles   YouM      YM-98
#
#    Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0      12100             181500          11.654820     21153.498820
# 1      10100             101000          11.560498     11676.102961
# 2      16100             112700           9.456886     10657.910157
# 3      20100             120600           6.935385      8364.074702
# 4       8100              24300          17.995663      4372.946230
#
#    Net Sales Value  Volume_zscore  Avg Price_zscore  Total Sales Value_zscore  \
# ...

# %%
# 7. One-Hot Encoding for Categorical Variables
dummy_df = pd.get_dummies(df, columns=cat_cols, drop_first=True)

print("===== DataFrame with Dummy Variables =====")
print(dummy_df.head())
# Out:
# ===== DataFrame with Dummy Variables =====
#    Volume  Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0      15      12100             181500          11.654820     21153.498820
# 1      10      10100             101000          11.560498     11676.102961
# 2       7      16100             112700           9.456886     10657.910157
# 3       6      20100             120600           6.935385      8364.074702
# 4       3       8100              24300          17.995663      4372.946230
#
#    Net Sales Value  Date_02-04-2021  Date_03-04-2021  Date_04-04-2021  \
# 0    160346.501180            False            False            False
# 1     89323.897039            False            False            False
# 2    102042.089843            False            False            False
# 3    112235.925298            False            False            False
# 4     19927.053770            False            False            False
#
# ...
